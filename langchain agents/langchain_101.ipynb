# %% [markdown]
# # Langchain 101

# %% [markdown]
# ## Key Concepts
#
# ### Prompts
#
# Prompts are the instructions or context you provide to the LLM to guide its output. [[LangChain]] provides a `PromptTemplate` class to make it easy to create and use prompts.
#
# Here's an example of creating a prompt template:

# %%
from langchain import PromptTemplate 
template = """
You are an assistant that helps users write professional emails. 

Given the following context:
{context} 

Write a professional email response. Sign the email as "John".
""" 

prompt = PromptTemplate(
						input_variables=["context"],
						template=template,)

# %% [markdown]
# You can then use the prompt by passing in the input variables:

# %%
context = "I need to inform my boss that I'll be taking a vacation next week."
print(prompt.format(context=context))
# Out:
# You are an assistant that helps users write professional emails.
#
# Given the following context:
# I need to inform my boss that I'll be taking a vacation next week.
#
# Write a professional email response. Sign the email as "John".

# %% [markdown]
# ### LLMs
# LangChain provides a standard interface for interacting with different LLM providers through the LLM class.
#
# Here's an example of using OpenAI's text-davinci-003 model:

# %%
import os
from dotenv import load_dotenv

load_dotenv()

api_key = os.environ["OPENAI_API_KEY"]

from langchain.llms import OpenAI
 
llm = OpenAI(
    # model_name="text-davinci-003",
    # model_name="gpt-3.5-turbo",
    model_name="gpt-3.5-turbo",
    openai_api_key=api_key
    )
 
result = llm("What is the capital of France?")
print(result)
# Out:
# c:\Users\metal\chatgpt_prompts\.venv\Lib\site-packages\langchain_community\llms\openai.py:254: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain_community.chat_models import ChatOpenAI`
#   warnings.warn(
# c:\Users\metal\chatgpt_prompts\.venv\Lib\site-packages\langchain_community\llms\openai.py:1075: UserWarning: You are trying to use a chat model. This way of initializing it is no longer supported. Instead, please use: `from langchain_community.chat_models import ChatOpenAI`
#   warnings.warn(
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[2], line 16
#       8 from langchain.llms import OpenAI
#      10 llm = OpenAI(
#      11     # model_name="text-davinci-003",
#      12     model_name="gpt-3.5-turbo",
#      13     openai_api_key=api_key
#      14     )
# ---> 16 result = llm("What is the capital of France?")
#      17 print(result)
#
# File c:\Users\metal\chatgpt_prompts\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:170, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     168     warned = True
#     169     emit_warning()
# --> 170 return wrapped(*args, **kwargs)
#
# File c:\Users\metal\chatgpt_prompts\.venv\Lib\site-packages\langchain_core\language_models\llms.py:1190, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1183 if not isinstance(prompt, str):
#    1184     raise ValueError(
#    1185         "Argument `prompt` is expected to be a string. Instead found "
#    1186         f"{type(prompt)}. If you want to run the LLM on multiple prompts, use "
#    1187         "`generate` instead."
#    1188     )
#    1189 return (
# -> 1190     self.generate(
#    1191         [prompt],
#    1192         stop=stop,
#    1193         callbacks=callbacks,
#    1194         tags=tags,
#    1195         metadata=metadata,
#    1196         **kwargs,
#    1197     )
#    1198     .generations[0][0]
#    1199     .text
#    1200 )
#
# File c:\Users\metal\chatgpt_prompts\.venv\Lib\site-packages\langchain_core\language_models\llms.py:880, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     865 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     866     run_managers = [
#     867         callback_manager.on_llm_start(
#     868             dumpd(self),
#    (...)
#     878         )
#     879     ]
# --> 880     output = self._generate_helper(
#     881         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     882     )
#     883     return output
#     884 if len(missing_prompts) > 0:
#
# File c:\Users\metal\chatgpt_prompts\.venv\Lib\site-packages\langchain_core\language_models\llms.py:738, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     736     for run_manager in run_managers:
#     737         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 738     raise e
#     739 flattened_outputs = output.flatten()
#     740 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File c:\Users\metal\chatgpt_prompts\.venv\Lib\site-packages\langchain_core\language_models\llms.py:725, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     715 def _generate_helper(
#     716     self,
#     717     prompts: List[str],
#    (...)
#     721     **kwargs: Any,
#     722 ) -> LLMResult:
#     723     try:
#     724         output = (
# --> 725             self._generate(
#     726                 prompts,
#     727                 stop=stop,
#     728                 # TODO: support multiple run managers
#     729                 run_manager=run_managers[0] if run_managers else None,
#     730                 **kwargs,
#     731             )
#     732             if new_arg_supported
#     733             else self._generate(prompts, stop=stop)
#     734         )
#     735     except BaseException as e:
#     736         for run_manager in run_managers:
#
# File c:\Users\metal\chatgpt_prompts\.venv\Lib\site-packages\langchain_community\llms\openai.py:1164, in OpenAIChat._generate(self, prompts, stop, run_manager, **kwargs)
#    1162 messages, params = self._get_chat_params(prompts, stop)
#    1163 params = {**params, **kwargs}
# -> 1164 full_response = completion_with_retry(
#    1165     self, messages=messages, run_manager=run_manager, **params
#    1166 )
#    1167 if not isinstance(full_response, dict):
#    1168     full_response = full_response.dict()
#
# File c:\Users\metal\chatgpt_prompts\.venv\Lib\site-packages\langchain_community\llms\openai.py:120, in completion_with_retry(llm, run_manager, **kwargs)
#     118 """Use tenacity to retry the completion call."""
#     119 if is_openai_v1():
# --> 120     return llm.client.create(**kwargs)
#     122 retry_decorator = _create_retry_decorator(llm, run_manager=run_manager)
#     124 @retry_decorator
#     125 def _completion_with_retry(**kwargs: Any) -> Any:
#
# File c:\Users\metal\chatgpt_prompts\.venv\Lib\site-packages\openai\lib\_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.ChatCompletion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# A detailed migration guide is available here: https://github.com/openai/openai-python/discussions/742
